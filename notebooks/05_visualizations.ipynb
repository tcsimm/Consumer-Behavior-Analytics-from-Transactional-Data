# %%
# 5 - visualizations

# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/thomassimmons/c/td/data/dirty_cafe_sales_cleaned.csv")

# %%
# Convert data types since using new file
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], errors='coerce')
df['Month'] = pd.to_datetime(df['Month'], errors='coerce')

# %%
# Top 10 best-selling items
plt.figure(figsize=(10,5))
top_items = df['Item'].value_counts().nlargest(10)
sns.barplot(x=top_items.values, y=top_items.index, palette='viridis')
plt.title("Top 10 Best-Selling Items")
plt.xlabel("Quantity Sold")
plt.ylabel("Item")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/kf/nt6wlgn90dvc9wsk7ttkqs4w0000gn/T/ipykernel_95051/309678422.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_items.values, y=top_items.index, palette='viridis')

# %%
# Revenue by month
monthly_revenue = df.groupby(df['Month'].dt.to_period("M"))['Total Spent'].sum()
monthly_revenue.plot(kind='line', marker='o', title="Monthly Revenue", figsize=(10, 5))
plt.ylabel("Revenue ($)")
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Payment method usage
plt.figure(figsize=(6, 4))
sns.countplot(data=df, y='Payment Method', order=df['Payment Method'].value_counts().index, palette="Set2")
plt.title("Payment Method Distribution")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/kf/nt6wlgn90dvc9wsk7ttkqs4w0000gn/T/ipykernel_95051/998365951.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='Payment Method', order=df['Payment Method'].value_counts().index, palette="Set2")

# %%
# Revenue by location
plt.figure(figsize=(6, 4))
location_revenue = df.groupby('Location')['Total Spent'].sum().sort_values()
sns.barplot(x=location_revenue.values, y=location_revenue.index, palette="Set3")
plt.title("Revenue by Location")
plt.xlabel("Total Revenue ($)")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/kf/nt6wlgn90dvc9wsk7ttkqs4w0000gn/T/ipykernel_95051/3090074840.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=location_revenue.values, y=location_revenue.index, palette="Set3")

# %%
# Distribution of Total Spent
plt.figure(figsize=(8, 4))
sns.histplot(df['Total Spent'], bins=30, kde=True, color="steelblue")
plt.title("Distribution of Total Spent")
plt.xlabel("Total Spent ($)")
plt.tight_layout()
plt.show()
